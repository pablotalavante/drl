# %%
#https://github.com/seungeunrho/minimalRL/blob/master/ddpg.py

# %%
from unityagents import UnityEnvironment
import numpy as np

import random
import collections
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.set_default_tensor_type('torch.DoubleTensor')

#Hyperparameters
lr_mu        = 0.0001
lr_q         = 0.0001
gamma        = 0.99
batch_size   = 128
buffer_limit = 100000
tau          = 0.001 # for target network soft update

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

class MuNet(nn.Module):
    def __init__(self):
        super(MuNet, self).__init__()
        self.fc1 = nn.Linear(33, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc_mu = nn.Linear(128, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x.double()))
        x = F.relu(self.fc2(x.double()))
        mu = torch.tanh(self.fc_mu(x))
        return mu

class QNet(nn.Module):
    def __init__(self):
        super(QNet, self).__init__()
        
        self.fc_s = nn.Linear(33, 256)
        #self.fc_a = nn.Linear(4,  28)
        self.fc_q = nn.Linear(260, 128)
        self.fc_3 = nn.Linear(128,  1)

    def forward(self, x, a):
        h1 = self.fc_s(x.double())
        h1 = F.relu(h1)
        
        a = torch.squeeze(a.double())
        #h2 = self.fc_a(a)
        #h2 = F.relu(h2)

        cat = torch.cat([h1, a], dim=1)
        q = F.relu(self.fc_q(cat))
        q = self.fc_3(q)
        return q

class OrnsteinUhlenbeckNoise:
    def __init__(self, mu):
        self.theta, self.dt, self.sigma = 0.15, 0.01, 0.2
        self.mu = mu
        self.x_prev = np.zeros_like(self.mu)

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x
      
def train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer):
    s,a,r,s_prime,done_mask  = memory.sample(batch_size)
    
    target = r + gamma * q_target(s_prime, mu_target(s_prime))
    q_loss = F.smooth_l1_loss(q(s,a), target.detach())
    q_optimizer.zero_grad()
    q_loss.backward()
    q_optimizer.step()
    
    mu_loss = -q(s,mu(s)).mean() # That's all for the policy loss.
    mu_optimizer.zero_grad()
    mu_loss.backward()
    mu_optimizer.step()
    
def soft_update(net, net_target):
    for param_target, param in zip(net_target.parameters(), net.parameters()):
        param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

# %%
env = UnityEnvironment(file_name='Reacher.app')

# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

memory = ReplayBuffer()

q, q_target = QNet(), QNet()
q_target.load_state_dict(q.state_dict())
mu, mu_target = MuNet(), MuNet()
mu_target.load_state_dict(mu.state_dict())

score = 0.0
print_interval = 1

mu_optimizer = optim.Adam(mu.parameters(), lr=lr_mu)
q_optimizer  = optim.Adam(q.parameters(), lr=lr_q)
ou_noise = OrnsteinUhlenbeckNoise(mu=np.zeros(4))

for n_epi in range(1000):
    env_info = env.reset(train_mode=True)[brain_name]
    s = env_info.vector_observations

    while True: # maximum length of episode is 200 for Pendulum-v0
        a = mu(torch.from_numpy(s)) 
        a = a.detach().numpy() + ou_noise()
        
        env_info = env.step(a)[brain_name]
        s_prime = env_info.vector_observations
        r = env_info.rewards[0]
        done = env_info.local_done
        
        memory.put((s[0], a[0], r,s_prime[0], done))
        score += r
        s = s_prime
        
        if memory.size() > batch_size:
            train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer)
            
            soft_update(mu, mu_target)
            soft_update(q,  q_target)
            
        if np.any(done):
            #print(f'episode {n_epi}: {score}')
            break
    
    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
        score = 0.0

env.close()
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# # of episode :1, avg score : 2.2
# # of episode :2, avg score : 0.3
# # of episode :3, avg score : 0.8
# # of episode :4, avg score : 0.4
# # of episode :5, avg score : 0.8
# # of episode :6, avg score : 0.5
# # of episode :7, avg score : 0.5
# # of episode :8, avg score : 0.5
# # of episode :9, avg score : 0.0
# # of episode :10, avg score : 0.7
# # of episode :11, avg score : 0.1
# # of episode :12, avg score : 1.2
# # of episode :13, avg score : 0.7
# # of episode :14, avg score : 0.4
# # of episode :15, avg score : 0.4
# # of episode :16, avg score : 0.5
# # of episode :17, avg score : 0.1
# # of episode :18, avg score : 0.0
# # of episode :19, avg score : 0.2
# # of episode :20, avg score : 1.5
# # of episode :21, avg score : 1.0
# # of episode :22, avg score : 0.6
# # of episode :23, avg score : 0.7
# # of episode :24, avg score : 0.7
# # of episode :25, avg score : 0.7
# # of episode :26, avg score : 1.3
# # of episode :27, avg score : 0.5
# # of episode :28, avg score : 1.0
# # of episode :29, avg score : 0.1
# # of episode :30, avg score : 0.7
# # of episode :31, avg score : 1.5
# # of episode :32, avg score : 0.4
# # of episode :33, avg score : 0.0
# # of episode :34, avg score : 0.1
# # of episode :35, avg score : 1.4
# # of episode :36, avg score : 0.4
# # of episode :37, avg score : 0.6
# # of episode :38, avg score : 0.1
# # of episode :39, avg score : 1.5
# # of episode :40, avg score : 0.5
# # of episode :41, avg score : 0.6
# # of episode :42, avg score : 0.3
# # of episode :43, avg score : 1.0
# # of episode :44, avg score : 0.7
# # of episode :45, avg score : 0.7
# # of episode :46, avg score : 0.2
# # of episode :47, avg score : 0.3
# # of episode :48, avg score : 1.3
# # of episode :49, avg score : 0.4
# # of episode :50, avg score : 0.0
# # of episode :51, avg score : 0.0
# # of episode :52, avg score : 0.3
# # of episode :53, avg score : 1.0
# # of episode :54, avg score : 1.3
# # of episode :55, avg score : 1.7
# # of episode :56, avg score : 1.9
# # of episode :57, avg score : 1.1
# # of episode :58, avg score : 4.1
# # of episode :59, avg score : 2.5
# # of episode :60, avg score : 0.6
# # of episode :61, avg score : 1.1
# # of episode :62, avg score : 1.8
# # of episode :63, avg score : 1.6
# # of episode :64, avg score : 1.7
# # of episode :65, avg score : 2.8
# # of episode :66, avg score : 0.5
# # of episode :67, avg score : 2.4
# # of episode :68, avg score : 0.6
# # of episode :69, avg score : 0.8
# # of episode :70, avg score : 2.6
# # of episode :71, avg score : 1.9
# # of episode :72, avg score : 1.8
# # of episode :73, avg score : 2.6
# # of episode :74, avg score : 4.3
# # of episode :75, avg score : 6.0
# # of episode :76, avg score : 1.2
# # of episode :77, avg score : 3.0
# # of episode :78, avg score : 0.5
# # of episode :79, avg score : 2.4
# # of episode :80, avg score : 2.7
# # of episode :81, avg score : 3.9
# # of episode :82, avg score : 5.2
# # of episode :83, avg score : 3.5
# # of episode :84, avg score : 2.6
# # of episode :85, avg score : 0.6
# # of episode :86, avg score : 3.8
# # of episode :87, avg score : 5.0
# # of episode :88, avg score : 3.2
# # of episode :89, avg score : 3.1
# # of episode :90, avg score : 3.6
# # of episode :91, avg score : 5.3
# # of episode :92, avg score : 5.4
# # of episode :93, avg score : 5.2
# # of episode :94, avg score : 5.2
# # of episode :95, avg score : 5.6
# # of episode :96, avg score : 2.2
# # of episode :97, avg score : 5.3
# # of episode :98, avg score : 4.0
# # of episode :99, avg score : 6.7
# # of episode :100, avg score : 5.3
# # of episode :101, avg score : 8.4
# # of episode :102, avg score : 5.6
# # of episode :103, avg score : 6.4
# # of episode :104, avg score : 3.7
# # of episode :105, avg score : 1.6
# # of episode :106, avg score : 7.2
# # of episode :107, avg score : 7.0
# # of episode :108, avg score : 8.8
# # of episode :109, avg score : 6.7
# # of episode :110, avg score : 6.6
# # of episode :111, avg score : 8.1
# # of episode :112, avg score : 5.8
# # of episode :113, avg score : 5.9
# # of episode :114, avg score : 7.3
# # of episode :115, avg score : 9.2
# # of episode :116, avg score : 8.4
# # of episode :117, avg score : 6.9
# # of episode :118, avg score : 6.5
# # of episode :119, avg score : 9.3
# # of episode :120, avg score : 9.0
# # of episode :121, avg score : 5.5
# # of episode :122, avg score : 11.1
# # of episode :123, avg score : 10.5
# # of episode :124, avg score : 9.8
# # of episode :125, avg score : 7.0
# # of episode :126, avg score : 7.0
# # of episode :127, avg score : 8.9
# # of episode :128, avg score : 12.0
# # of episode :129, avg score : 9.3
# # of episode :130, avg score : 11.8
# # of episode :131, avg score : 11.9
# # of episode :132, avg score : 8.7
# # of episode :133, avg score : 10.9
# # of episode :134, avg score : 11.4
# # of episode :135, avg score : 13.9
# # of episode :136, avg score : 11.9
# # of episode :137, avg score : 12.8
# # of episode :138, avg score : 6.6
# # of episode :139, avg score : 11.4
# # of episode :140, avg score : 7.6
# # of episode :141, avg score : 16.3
# # of episode :142, avg score : 8.6
# # of episode :143, avg score : 12.3
# # of episode :144, avg score : 13.2
# # of episode :145, avg score : 19.1
# # of episode :146, avg score : 10.9
# # of episode :147, avg score : 9.2
# # of episode :148, avg score : 12.9
# # of episode :149, avg score : 13.8
# # of episode :150, avg score : 13.1
# # of episode :151, avg score : 12.7
# # of episode :152, avg score : 12.0
# # of episode :153, avg score : 12.1
# # of episode :154, avg score : 18.0
# # of episode :155, avg score : 16.7
# # of episode :156, avg score : 13.8
# # of episode :157, avg score : 9.9
# # of episode :158, avg score : 15.2
# # of episode :159, avg score : 17.0
# # of episode :160, avg score : 17.7
# # of episode :161, avg score : 17.1
# # of episode :162, avg score : 5.6
# # of episode :163, avg score : 8.6
# # of episode :164, avg score : 15.7
# # of episode :165, avg score : 15.1
# # of episode :166, avg score : 16.1
# # of episode :167, avg score : 25.0
# # of episode :168, avg score : 8.8
# # of episode :169, avg score : 17.8
# # of episode :170, avg score : 13.3
# # of episode :171, avg score : 8.7
# # of episode :172, avg score : 16.2
# # of episode :173, avg score : 19.5
# # of episode :174, avg score : 23.7
# # of episode :175, avg score : 20.7
# # of episode :176, avg score : 16.0
# # of episode :177, avg score : 26.0
# # of episode :178, avg score : 20.9
# # of episode :179, avg score : 17.0
# # of episode :180, avg score : 16.3
# # of episode :181, avg score : 17.8
# # of episode :182, avg score : 19.8
# # of episode :183, avg score : 19.0
# # of episode :184, avg score : 14.8
# # of episode :185, avg score : 20.3
# # of episode :186, avg score : 24.5
# # of episode :187, avg score : 23.7
# # of episode :188, avg score : 24.0
# # of episode :189, avg score : 22.3
# # of episode :190, avg score : 18.7
# # of episode :191, avg score : 29.5
# # of episode :192, avg score : 18.2
# # of episode :193, avg score : 20.8
# # of episode :194, avg score : 23.1
# # of episode :195, avg score : 11.4
# # of episode :196, avg score : 14.4
# # of episode :197, avg score : 27.4
# # of episode :198, avg score : 24.5
# # of episode :199, avg score : 21.2
# # of episode :200, avg score : 15.7
# # of episode :201, avg score : 17.6
# # of episode :202, avg score : 24.1
# # of episode :203, avg score : 22.4
# # of episode :204, avg score : 20.6
# # of episode :205, avg score : 13.1
# # of episode :206, avg score : 11.0
# # of episode :207, avg score : 18.0
# # of episode :208, avg score : 22.5
# # of episode :209, avg score : 19.4
# # of episode :210, avg score : 19.5
# # of episode :211, avg score : 15.8
# # of episode :212, avg score : 21.4
# # of episode :213, avg score : 18.9
# # of episode :214, avg score : 14.2
# # of episode :215, avg score : 25.7
# # of episode :216, avg score : 19.7
# # of episode :217, avg score : 20.8
# # of episode :218, avg score : 28.6
# # of episode :219, avg score : 14.5
# # of episode :220, avg score : 19.1
# # of episode :221, avg score : 22.7
# # of episode :222, avg score : 23.8
# # of episode :223, avg score : 26.4
# # of episode :224, avg score : 19.2
# # of episode :225, avg score : 21.6
# # of episode :226, avg score : 26.2
# # of episode :227, avg score : 24.4
# # of episode :228, avg score : 33.6
# # of episode :229, avg score : 21.6
# # of episode :230, avg score : 30.4
# # of episode :231, avg score : 20.3
# # of episode :232, avg score : 15.5
# # of episode :233, avg score : 29.6
# # of episode :234, avg score : 19.8
# # of episode :235, avg score : 28.2
# # of episode :236, avg score : 26.4
# # of episode :237, avg score : 27.6
# # of episode :238, avg score : 30.6
# # of episode :239, avg score : 31.8
# # of episode :240, avg score : 29.6
# # of episode :241, avg score : 30.3
# # of episode :242, avg score : 27.6
# # of episode :243, avg score : 30.6
# # of episode :244, avg score : 24.8
# # of episode :245, avg score : 29.2
# # of episode :246, avg score : 28.4
# # of episode :247, avg score : 32.4
# # of episode :248, avg score : 28.2
# # of episode :249, avg score : 24.8
# # of episode :250, avg score : 31.6
# # of episode :251, avg score : 30.1
# # of episode :252, avg score : 21.6
# # of episode :253, avg score : 21.0
# # of episode :254, avg score : 37.6
# # of episode :255, avg score : 23.9
# # of episode :256, avg score : 28.1
# # of episode :257, avg score : 33.0
# # of episode :258, avg score : 29.0
# # of episode :259, avg score : 28.7
# # of episode :260, avg score : 34.3
# # of episode :261, avg score : 32.7
# # of episode :262, avg score : 26.0
# # of episode :263, avg score : 33.4
# # of episode :264, avg score : 25.1
# # of episode :265, avg score : 33.0
# # of episode :266, avg score : 33.9
# # of episode :267, avg score : 35.6
# # of episode :268, avg score : 34.5
# # of episode :269, avg score : 35.4
# # of episode :270, avg score : 35.5
# # of episode :271, avg score : 35.1
# # of episode :272, avg score : 31.7
# # of episode :273, avg score : 34.0
# # of episode :274, avg score : 35.0
# # of episode :275, avg score : 34.7
# # of episode :276, avg score : 34.4
# # of episode :277, avg score : 35.6
# # of episode :278, avg score : 34.1
# # of episode :279, avg score : 30.5
# # of episode :280, avg score : 35.3
# # of episode :281, avg score : 32.9
# # of episode :282, avg score : 30.1
# # of episode :283, avg score : 34.4
# # of episode :284, avg score : 24.5
# # of episode :285, avg score : 22.2
# # of episode :286, avg score : 30.9
# # of episode :287, avg score : 28.1
# # of episode :288, avg score : 13.4
# # of episode :289, avg score : 24.9
# # of episode :290, avg score : 31.8
# # of episode :291, avg score : 34.1
# # of episode :292, avg score : 36.2
# # of episode :293, avg score : 30.2
# # of episode :294, avg score : 32.5
# # of episode :295, avg score : 28.8
# # of episode :296, avg score : 34.9
# # of episode :297, avg score : 30.5
# # of episode :298, avg score : 31.8
# # of episode :299, avg score : 34.3
# # of episode :300, avg score : 36.2
# # of episode :301, avg score : 27.9
# # of episode :302, avg score : 36.0
# # of episode :303, avg score : 13.3
# # of episode :304, avg score : 31.2
# # of episode :305, avg score : 28.6
# # of episode :306, avg score : 22.2
# # of episode :307, avg score : 31.2
# # of episode :308, avg score : 32.4
# # of episode :309, avg score : 25.9
# # of episode :310, avg score : 29.5
# # of episode :311, avg score : 34.0
# # of episode :312, avg score : 31.0
# # of episode :313, avg score : 30.3
# # of episode :314, avg score : 30.9
# # of episode :315, avg score : 29.6
# # of episode :316, avg score : 29.5
# # of episode :317, avg score : 30.3
# # of episode :318, avg score : 33.9
# # of episode :319, avg score : 37.1
# # of episode :320, avg score : 19.6
# # of episode :321, avg score : 38.2
# # of episode :322, avg score : 30.3
# # of episode :323, avg score : 34.4
# # of episode :324, avg score : 33.5
# # of episode :325, avg score : 34.3
# # of episode :326, avg score : 32.4
# # of episode :327, avg score : 36.9
# # of episode :328, avg score : 31.8
# # of episode :329, avg score : 26.7
# # of episode :330, avg score : 25.0
# # of episode :331, avg score : 30.1
# # of episode :332, avg score : 26.4
# # of episode :333, avg score : 16.1
# # of episode :334, avg score : 19.3
# # of episode :335, avg score : 22.2
# # of episode :336, avg score : 37.6
# # of episode :337, avg score : 38.3
# # of episode :338, avg score : 31.2
# # of episode :339, avg score : 31.8
# # of episode :340, avg score : 36.0
# # of episode :341, avg score : 9.1
# # of episode :342, avg score : 30.8
# # of episode :343, avg score : 35.9
# # of episode :344, avg score : 17.0
# # of episode :345, avg score : 18.7
# # of episode :346, avg score : 30.8
# # of episode :347, avg score : 33.0
# # of episode :348, avg score : 38.8
# # of episode :349, avg score : 37.0
# # of episode :350, avg score : 39.1
# # of episode :351, avg score : 20.7
# # of episode :352, avg score : 22.7
# # of episode :353, avg score : 27.8
# # of episode :354, avg score : 29.3
# # of episode :355, avg score : 29.8
# # of episode :356, avg score : 34.3
# # of episode :357, avg score : 27.2
# # of episode :358, avg score : 30.2
# # of episode :359, avg score : 34.4
# # of episode :360, avg score : 34.3
# # of episode :361, avg score : 31.2
# # of episode :362, avg score : 27.6
# # of episode :363, avg score : 37.8
# # of episode :364, avg score : 20.9
# # of episode :365, avg score : 25.9
# # of episode :366, avg score : 20.4
# # of episode :367, avg score : 32.1
# # of episode :368, avg score : 21.7
# # of episode :369, avg score : 29.7
# # of episode :370, avg score : 31.3
# # of episode :371, avg score : 23.4
# # of episode :372, avg score : 33.6
# # of episode :373, avg score : 25.2
# # of episode :374, avg score : 26.6
# # of episode :375, avg score : 30.5
# # of episode :376, avg score : 29.3
# # of episode :377, avg score : 39.0
# # of episode :378, avg score : 17.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2c60d8bad135> in <module>
#      27         a = a.detach().numpy() + ou_noise()
#      28
# ---> 29         env_info = env.step(a)[brain_name]
#      30         s_prime = env_info.vector_observations
#      31         r = env_info.rewards[0]
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/unityagents/environment.py in step(self, vector_action, memory, text_action)
#     367
#     368             outputs = self.communicator.exchange(
# --> 369                 self._generate_step_input(vector_action, memory, text_action)
#     370             )
#     371             if outputs is None:
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/unityagents/rpc_communicator.py in exchange(self, inputs)
#      76         message.unity_input.CopyFrom(inputs)
#      77         self.unity_to_external.parent_conn.send(message)
# ---> 78         output = self.unity_to_external.parent_conn.recv()
#      79         if output.header.status != 200:
#      80             return None
#
# ~/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
torch.save(mu.state_dict(), 'mu.pth')
torch.save(q.state_dict(), 'q.pth')

# %%
q
# Out:
# QNet(
#   (fc_s): Linear(in_features=33, out_features=256, bias=True)
#   (fc_q): Linear(in_features=260, out_features=128, bias=True)
#   (fc_3): Linear(in_features=128, out_features=1, bias=True)
# )
