# %% [markdown]
# # Continuous Control
#
# ---

# %%
from collections import deque

from unityagents import UnityEnvironment
import numpy as np

import random
import collections
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.set_default_tensor_type('torch.DoubleTensor')

#Hyperparameters
lr_mu        = 0.0001
lr_q         = 0.0001
gamma        = 0.99
batch_size   = 128
buffer_limit = 100000
tau          = 0.001 # for target network soft update

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

class MuNet(nn.Module):
    def __init__(self):
        super(MuNet, self).__init__()
        self.fc1 = nn.Linear(33, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc_mu = nn.Linear(128, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x.double()))
        x = F.relu(self.fc2(x.double()))
        mu = torch.tanh(self.fc_mu(x))
        return mu

class QNet(nn.Module):
    def __init__(self):
        super(QNet, self).__init__()
        
        self.fc_s = nn.Linear(33, 256)
        #self.fc_a = nn.Linear(4,  28)
        self.fc_q = nn.Linear(260, 128)
        self.fc_3 = nn.Linear(128,  1)

    def forward(self, x, a):
        h1 = self.fc_s(x.double())
        h1 = F.relu(h1)
        
        a = torch.squeeze(a.double())
        #h2 = self.fc_a(a)
        #h2 = F.relu(h2)

        cat = torch.cat([h1, a], dim=1)
        q = F.relu(self.fc_q(cat))
        q = self.fc_3(q)
        return q

class OrnsteinUhlenbeckNoise:
    def __init__(self, mu):
        self.theta, self.dt, self.sigma = 0.15, 0.01, 0.2
        self.mu = mu
        self.x_prev = np.zeros_like(self.mu)

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x
      
def train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer):
    s,a,r,s_prime,done_mask  = memory.sample(batch_size)
    
    target = r + gamma * q_target(s_prime, mu_target(s_prime))
    q_loss = F.smooth_l1_loss(q(s,a), target.detach())
    q_optimizer.zero_grad()
    q_loss.backward()
    q_optimizer.step()
    
    mu_loss = -q(s,mu(s)).mean() # That's all for the policy loss.
    mu_optimizer.zero_grad()
    mu_loss.backward()
    mu_optimizer.step()
    
def soft_update(net, net_target):
    for param_target, param in zip(net_target.parameters(), net.parameters()):
        param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

# %%
#env = UnityEnvironment(file_name='Reacher.app')
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

memory = ReplayBuffer()

q, q_target = QNet(), QNet()
q_target.load_state_dict(q.state_dict())
mu, mu_target = MuNet(), MuNet()
mu_target.load_state_dict(mu.state_dict())

score = 0.0
print_interval = 1

mu_optimizer = optim.Adam(mu.parameters(), lr=lr_mu)
q_optimizer  = optim.Adam(q.parameters(), lr=lr_q)
ou_noise = OrnsteinUhlenbeckNoise(mu=np.zeros(4))

reward_buffer = deque(maxlen=100)
reward_hist = []
softened_reward = []

for n_epi in range(1000):
    env_info = env.reset(train_mode=True)[brain_name]
    s = env_info.vector_observations

    while True: # maximum length of episode is 200 for Pendulum-v0
        a = mu(torch.from_numpy(s)) 
        a = a.detach().numpy() + ou_noise()
        
        env_info = env.step(a)[brain_name]
        s_prime = env_info.vector_observations
        r = env_info.rewards[0]
        done = env_info.local_done
        
        memory.put((s[0], a[0], r,s_prime[0], done))
        score += r
        s = s_prime
        
        if memory.size() > batch_size:
            train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer)
            
            soft_update(mu, mu_target)
            soft_update(q,  q_target)
            
        if np.any(done):
            #print(f'episode {n_epi}: {score}')l
            reward_buffer.append(score)
            reward_hist.append(score)
            softened_reward.append(np.mean(reward_buffer))
            break
    
    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode :{}, avg score : {:.1f}, score {}".format(n_epi, np.mean(reward_buffer), score))
        score = 0.0
    
    if np.mean(reward_buffer) > 30:
        print('Solved!')
    
env.close()
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# # of episode :1, avg score : 0.4, score 0.8099999818950891
# # of episode :2, avg score : 0.5, score 0.6999999843537807
# # of episode :3, avg score : 0.5, score 0.3199999928474426
# # of episode :4, avg score : 0.4, score 0.23999999463558197
# # of episode :5, avg score : 0.5, score 0.6599999852478504
# # of episode :6, avg score : 0.5, score 0.7099999841302633
# # of episode :7, avg score : 0.6, score 1.2499999720603228
# # of episode :8, avg score : 0.6, score 0.46999998949468136
# # of episode :9, avg score : 0.6, score 1.1399999745190144
# # of episode :10, avg score : 0.7, score 0.9399999789893627
# # of episode :11, avg score : 0.6, score 0.2199999950826168
# # of episode :12, avg score : 0.6, score 0.5699999872595072
# # of episode :13, avg score : 0.8, score 2.509999943897128
# # of episode :14, avg score : 0.8, score 1.529999965801835
# # of episode :15, avg score : 0.9, score 1.6899999622255564
# # of episode :16, avg score : 0.9, score 1.409999968484044
# # of episode :17, avg score : 0.9, score 0.3799999915063381
# # of episode :18, avg score : 0.9, score 1.4899999666959047
# # of episode :19, avg score : 0.9, score 0.4599999897181988
# # of episode :20, avg score : 0.9, score 1.9899999555200338
# # of episode :21, avg score : 0.9, score 0.4499999899417162
# # of episode :22, avg score : 0.9, score 0.9499999787658453
# # of episode :23, avg score : 0.9, score 1.3699999693781137
# # of episode :24, avg score : 0.9, score 0.36999999172985554
# # of episode :25, avg score : 0.9, score 1.2399999722838402
# # of episode :26, avg score : 1.0, score 1.8799999579787254
# # of episode :27, avg score : 1.0, score 2.5899999421089888
# # of episode :28, avg score : 1.0, score 1.169999973848462
# # of episode :29, avg score : 1.0, score 0.2799999937415123
# # of episode :30, avg score : 1.0, score 1.2799999713897705
# # of episode :31, avg score : 1.0, score 1.389999968931079
# # of episode :32, avg score : 1.0, score 0.6299999859184027
# # of episode :33, avg score : 1.0, score 1.769999960437417
# # of episode :34, avg score : 1.0, score 0.979999978095293
# # of episode :35, avg score : 1.0, score 1.1099999751895666
# # of episode :36, avg score : 1.0, score 1.579999964684248
# # of episode :37, avg score : 1.1, score 1.8799999579787254
# # of episode :38, avg score : 1.1, score 1.9899999555200338
# # of episode :39, avg score : 1.1, score 0.6099999863654375
# # of episode :40, avg score : 1.1, score 2.799999937415123
# # of episode :41, avg score : 1.1, score 0.029999999329447746
# # of episode :42, avg score : 1.1, score 0.5799999870359898
# # of episode :43, avg score : 1.1, score 0.8199999816715717
# # of episode :44, avg score : 1.1, score 0.41999999061226845
# # of episode :45, avg score : 1.1, score 1.6299999635666609
# # of episode :46, avg score : 1.1, score 0.8799999803304672
# # of episode :47, avg score : 1.1, score 1.50999996624887
# # of episode :48, avg score : 1.1, score 1.099999975413084
# # of episode :49, avg score : 1.1, score 2.12999995239079
# # of episode :50, avg score : 1.1, score 0.7599999830126762
# # of episode :51, avg score : 1.1, score 2.2599999494850636
# # of episode :52, avg score : 1.2, score 3.2699999269098043
# # of episode :53, avg score : 1.1, score 0.8099999818950891
# # of episode :54, avg score : 1.2, score 4.849999891594052
# # of episode :55, avg score : 1.2, score 2.7599999383091927
# # of episode :56, avg score : 1.3, score 2.5199999436736107
# # of episode :57, avg score : 1.3, score 1.8799999579787254
# # of episode :58, avg score : 1.3, score 2.819999936968088
# # of episode :59, avg score : 1.3, score 0.19999999552965164
# # of episode :60, avg score : 1.3, score 2.459999945014715
# # of episode :61, avg score : 1.4, score 5.069999886676669
# # of episode :62, avg score : 1.4, score 2.869999935850501
# # of episode :63, avg score : 1.4, score 1.7499999608844519
# # of episode :64, avg score : 1.5, score 4.999999888241291
# # of episode :65, avg score : 1.5, score 4.099999908357859
# # of episode :66, avg score : 1.5, score 4.359999902546406
# # of episode :67, avg score : 1.6, score 3.249999927356839
# # of episode :68, avg score : 1.6, score 4.009999910369515
# # of episode :69, avg score : 1.6, score 3.0799999311566353
# # of episode :70, avg score : 1.7, score 4.649999896064401
# # of episode :71, avg score : 1.7, score 5.219999883323908
# # of episode :72, avg score : 1.7, score 2.509999943897128
# # of episode :73, avg score : 1.7, score 2.1399999521672726
# # of episode :74, avg score : 1.7, score 3.299999926239252
# # of episode :75, avg score : 1.8, score 3.0799999311566353
# # of episode :76, avg score : 1.8, score 3.779999915510416
# # of episode :77, avg score : 1.8, score 2.5499999430030584
# # of episode :78, avg score : 1.8, score 3.0299999322742224
# # of episode :79, avg score : 1.8, score 1.4999999664723873
# # of episode :80, avg score : 1.8, score 3.7199999168515205
# # of episode :81, avg score : 1.9, score 4.349999902769923
# # of episode :82, avg score : 1.9, score 6.839999847114086
# # of episode :83, avg score : 2.0, score 6.179999861866236
# # of episode :84, avg score : 2.0, score 6.339999858289957
# # of episode :85, avg score : 2.0, score 3.399999924004078
# # of episode :86, avg score : 2.1, score 4.789999892935157
# # of episode :87, avg score : 2.1, score 5.80999987013638
# # of episode :88, avg score : 2.1, score 3.159999929368496
# # of episode :89, avg score : 2.2, score 5.139999885112047
# # of episode :90, avg score : 2.2, score 5.069999886676669
# # of episode :91, avg score : 2.2, score 6.539999853819609
# # of episode :92, avg score : 2.2, score 2.969999933615327
# # of episode :93, avg score : 2.3, score 11.519999742507935
# # of episode :94, avg score : 2.4, score 5.339999880641699
# # of episode :95, avg score : 2.4, score 4.859999891370535
# # of episode :96, avg score : 2.4, score 1.699999962002039
# # of episode :97, avg score : 2.4, score 5.449999878183007
# # of episode :98, avg score : 2.4, score 2.0699999537318945
# # of episode :99, avg score : 2.4, score 3.9799999110400677
# # of episode :100, avg score : 2.5, score 4.489999899640679
# # of episode :101, avg score : 2.5, score 6.6399998515844345
# # of episode :102, avg score : 2.6, score 8.819999802857637
# # of episode :103, avg score : 2.7, score 11.22999974898994
# # of episode :104, avg score : 2.8, score 4.969999888911843
# # of episode :105, avg score : 2.8, score 3.7499999161809683
# # of episode :106, avg score : 2.9, score 4.709999894723296
# # of episode :107, avg score : 2.9, score 10.519999764859676
# # of episode :108, avg score : 3.0, score 2.3299999479204416
# # of episode :109, avg score : 3.0, score 7.959999822080135
# # of episode :110, avg score : 3.1, score 9.939999777823687
# # of episode :111, avg score : 3.2, score 5.569999875500798
# # of episode :112, avg score : 3.2, score 6.9499998446553946
# # of episode :113, avg score : 3.3, score 6.479999855160713
# # of episode :114, avg score : 3.3, score 4.819999892264605
# # of episode :115, avg score : 3.3, score 4.769999893382192
# # of episode :116, avg score : 3.4, score 11.669999739155173
# # of episode :117, avg score : 3.5, score 9.039999797940254
# # of episode :118, avg score : 3.6, score 6.73999984934926
# # of episode :119, avg score : 3.6, score 4.789999892935157
# # of episode :120, avg score : 3.7, score 6.4499998558312654
# # of episode :121, avg score : 3.7, score 8.139999818056822
# # of episode :122, avg score : 3.8, score 8.90999980084598
# # of episode :123, avg score : 3.9, score 5.749999871477485
# # of episode :124, avg score : 3.9, score 7.1199998408555984
# # of episode :125, avg score : 4.0, score 6.129999862983823
# # of episode :126, avg score : 4.1, score 9.249999793246388
# # of episode :127, avg score : 4.1, score 3.159999929368496
# # of episode :128, avg score : 4.1, score 6.169999862089753
# # of episode :129, avg score : 4.2, score 9.48999978788197
# # of episode :130, avg score : 4.3, score 14.309999680146575
# # of episode :131, avg score : 4.4, score 7.489999832585454
# # of episode :132, avg score : 4.6, score 18.369999589398503
# # of episode :133, avg score : 4.7, score 10.509999765083194
# # of episode :134, avg score : 4.8, score 15.649999650195241
# # of episode :135, avg score : 4.9, score 7.969999821856618
# # of episode :136, avg score : 5.0, score 8.669999806210399
# # of episode :137, avg score : 5.0, score 6.649999851360917
# # of episode :138, avg score : 5.0, score 6.799999848008156
# # of episode :139, avg score : 5.1, score 8.839999802410603
# # of episode :140, avg score : 5.2, score 5.7799998708069324
# # of episode :141, avg score : 5.2, score 5.549999875947833
# # of episode :142, avg score : 5.3, score 8.16999981738627
# # of episode :143, avg score : 5.4, score 11.639999739825726
# # of episode :144, avg score : 5.5, score 8.269999815151095
# # of episode :145, avg score : 5.6, score 13.819999691098928
# # of episode :146, avg score : 5.7, score 8.099999818950891
# # of episode :147, avg score : 5.8, score 9.769999781623483
# # of episode :148, avg score : 5.8, score 6.939999844878912
# # of episode :149, avg score : 5.9, score 14.799999669194221
# # of episode :150, avg score : 6.1, score 12.059999730437994
# # of episode :151, avg score : 6.1, score 6.539999853819609
# # of episode :152, avg score : 6.1, score 6.289999859407544
# # of episode :153, avg score : 6.2, score 10.829999757930636
# # of episode :154, avg score : 6.3, score 10.169999772682786
# # of episode :155, avg score : 6.4, score 14.529999675229192
# # of episode :156, avg score : 6.4, score 5.639999873936176
# # of episode :157, avg score : 6.6, score 15.29999965801835
# # of episode :158, avg score : 6.6, score 5.619999874383211
# # of episode :159, avg score : 6.7, score 12.849999712780118
# # of episode :160, avg score : 6.8, score 14.589999673888087
# # of episode :161, avg score : 6.9, score 8.78999980352819
# # of episode :162, avg score : 7.0, score 10.779999759048223
# # of episode :163, avg score : 7.1, score 12.319999724626541
# # of episode :164, avg score : 7.1, score 11.88999973423779
# # of episode :165, avg score : 7.2, score 12.519999720156193
# # of episode :166, avg score : 7.3, score 12.999999709427357
# # of episode :167, avg score : 7.5, score 22.72999949194491
# # of episode :168, avg score : 7.6, score 15.509999653324485
# # of episode :169, avg score : 7.6, score 4.659999895840883
# # of episode :170, avg score : 7.7, score 10.319999769330025
# # of episode :171, avg score : 7.7, score 10.489999765530229
# # of episode :172, avg score : 7.8, score 14.069999685510993
# # of episode :173, avg score : 7.9, score 9.63999978452921
# # of episode :174, avg score : 8.0, score 9.209999794140458
# # of episode :175, avg score : 8.1, score 12.369999723508954
# # of episode :176, avg score : 8.2, score 15.109999662265182
# # of episode :177, avg score : 8.4, score 22.69999949261546
# # of episode :178, avg score : 8.4, score 8.16999981738627
# # of episode :179, avg score : 8.5, score 10.14999977312982
# # of episode :180, avg score : 8.6, score 9.339999791234732
# # of episode :181, avg score : 8.6, score 8.469999810680747
# # of episode :182, avg score : 8.8, score 22.839999489486217
# # of episode :183, avg score : 8.9, score 15.359999656677246
# # of episode :184, avg score : 9.0, score 13.639999695122242
# # of episode :185, avg score : 9.0, score 10.189999772235751
# # of episode :186, avg score : 9.1, score 12.139999728649855
# # of episode :187, avg score : 9.2, score 14.649999672546983
# # of episode :188, avg score : 9.3, score 16.03999964147806
# # of episode :189, avg score : 9.4, score 13.489999698475003
# # of episode :190, avg score : 9.5, score 13.78999969176948
# # of episode :191, avg score : 9.6, score 17.869999600574374
# # of episode :192, avg score : 9.7, score 12.919999711215496
# # of episode :193, avg score : 9.7, score 12.379999723285437
# # of episode :194, avg score : 9.8, score 13.579999696463346
# # of episode :195, avg score : 9.8, score 2.9299999345093966
# # of episode :196, avg score : 9.9, score 14.279999680817127
# # of episode :197, avg score : 10.0, score 18.97999957576394
# # of episode :198, avg score : 10.2, score 19.799999557435513
# # of episode :199, avg score : 10.3, score 9.119999796152115
# # of episode :200, avg score : 10.3, score 11.009999753907323
# # of episode :201, avg score : 10.5, score 21.279999524354935
# # of episode :202, avg score : 10.6, score 21.819999512284994
# # of episode :203, avg score : 10.6, score 13.519999697804451
# # of episode :204, avg score : 10.7, score 16.049999641254544
# # of episode :205, avg score : 11.0, score 26.509999407455325
# # of episode :206, avg score : 11.1, score 16.49999963119626
# # of episode :207, avg score : 11.1, score 12.659999717026949
# # of episode :208, avg score : 11.3, score 19.839999556541443
# # of episode :209, avg score : 11.4, score 18.35999958962202
# # of episode :210, avg score : 11.5, score 18.599999584257603
# # of episode :211, avg score : 11.6, score 14.539999675005674
# # of episode :212, avg score : 11.7, score 17.14999961666763
# # of episode :213, avg score : 11.8, score 25.389999432489276
# # of episode :214, avg score : 12.0, score 19.109999572858214
# # of episode :215, avg score : 12.2, score 24.24999945797026
# # of episode :216, avg score : 12.3, score 19.219999570399523
# # of episode :217, avg score : 12.4, score 18.689999582245946
# # of episode :218, avg score : 12.5, score 22.899999488145113
# # of episode :219, avg score : 12.6, score 12.089999729767442
# # of episode :220, avg score : 12.7, score 17.359999611973763
# # of episode :221, avg score : 12.8, score 23.19999948143959
# # of episode :222, avg score : 12.9, score 12.719999715685844
# # of episode :223, avg score : 13.0, score 14.689999671652913
# # of episode :224, avg score : 13.1, score 19.769999558106065
# # of episode :225, avg score : 13.2, score 11.419999744743109
# # of episode :226, avg score : 13.2, score 12.129999728873372
# # of episode :227, avg score : 13.4, score 22.019999507814646
# # of episode :228, avg score : 13.6, score 32.749999267980456
# # of episode :229, avg score : 13.7, score 19.299999568611383
# # of episode :230, avg score : 13.9, score 31.609999293461442
# # of episode :231, avg score : 14.0, score 19.519999563694
# # of episode :232, avg score : 14.0, score 19.239999569952488
# # of episode :233, avg score : 14.1, score 11.739999737590551
# # of episode :234, avg score : 14.0, score 10.659999761730433
# # of episode :235, avg score : 14.1, score 20.36999954469502
# # of episode :236, avg score : 14.1, score 10.739999759942293
# # of episode :237, avg score : 14.3, score 22.009999508038163
# # of episode :238, avg score : 14.5, score 25.09999943897128
# # of episode :239, avg score : 14.6, score 25.529999429360032
# # of episode :240, avg score : 14.8, score 21.2999995239079
# # of episode :241, avg score : 14.9, score 11.829999735578895
# # of episode :242, avg score : 15.0, score 22.07999950647354
# # of episode :243, avg score : 15.1, score 17.409999610856175
# # of episode :244, avg score : 15.2, score 23.339999478310347
# # of episode :245, avg score : 15.2, score 16.68999962694943
# # of episode :246, avg score : 15.4, score 18.97999957576394
# # of episode :247, avg score : 15.5, score 23.719999469816685
# # of episode :248, avg score : 15.6, score 13.859999690204859
# # of episode :249, avg score : 15.6, score 16.599999628961086
# # of episode :250, avg score : 15.7, score 20.469999542459846
# # of episode :251, avg score : 15.8, score 21.579999517649412
# # of episode :252, avg score : 15.9, score 18.039999596774578
# # of episode :253, avg score : 16.0, score 17.76999960280955
# # of episode :254, avg score : 16.2, score 26.319999411702156
# # of episode :255, avg score : 16.2, score 20.749999536201358
# # of episode :256, avg score : 16.3, score 17.799999602138996
# # of episode :257, avg score : 16.4, score 23.00999948568642
# # of episode :258, avg score : 16.6, score 21.859999511390924
# # of episode :259, avg score : 16.6, score 15.969999643042684
# # of episode :260, avg score : 16.7, score 25.079999439418316
# # of episode :261, avg score : 16.9, score 25.16999943740666
# # of episode :262, avg score : 17.0, score 20.82999953441322
# # of episode :263, avg score : 17.1, score 20.889999533072114
# # of episode :264, avg score : 17.1, score 15.129999661818147
# # of episode :265, avg score : 17.1, score 16.179999638348818
# # of episode :266, avg score : 17.2, score 22.95999948680401
# # of episode :267, avg score : 17.2, score 18.729999581351876
# # of episode :268, avg score : 17.3, score 21.429999521002173
# # of episode :269, avg score : 17.4, score 15.129999661818147
# # of episode :270, avg score : 17.4, score 15.549999652430415
# # of episode :271, avg score : 17.5, score 20.979999531060457
# # of episode :272, avg score : 17.6, score 18.059999596327543
# # of episode :273, avg score : 17.7, score 22.009999508038163
# # of episode :274, avg score : 17.8, score 22.11999950557947
# # of episode :275, avg score : 17.9, score 23.479999475181103
# # of episode :276, avg score : 18.0, score 23.909999465569854
# # of episode :277, avg score : 18.2, score 38.819999132305384
# # of episode :278, avg score : 18.3, score 22.95999948680401
# # of episode :279, avg score : 18.5, score 24.81999944522977
# # of episode :280, avg score : 18.6, score 22.709999492391944
# # of episode :281, avg score : 18.7, score 19.70999955944717
# # of episode :282, avg score : 18.8, score 29.12999934889376
# # of episode :283, avg score : 18.8, score 18.31999959051609
# # of episode :284, avg score : 18.8, score 9.05999979749322
# # of episode :285, avg score : 18.9, score 21.7599995136261
# # of episode :286, avg score : 19.0, score 24.86999944411218
# # of episode :287, avg score : 19.0, score 15.48999965377152
# # of episode :288, avg score : 19.0, score 11.379999745637178
# # of episode :289, avg score : 19.0, score 13.819999691098928
# # of episode :290, avg score : 19.1, score 26.05999941751361
# # of episode :291, avg score : 19.2, score 23.759999468922615
# # of episode :292, avg score : 19.3, score 23.529999474063516
# # of episode :293, avg score : 19.3, score 18.679999582469463
# # of episode :294, avg score : 19.4, score 24.019999463111162
# # of episode :295, avg score : 19.6, score 19.809999557211995
# # of episode :296, avg score : 19.7, score 23.639999471604824
# # of episode :297, avg score : 19.7, score 22.18999950401485
# # of episode :298, avg score : 19.7, score 22.80999949015677
# # of episode :299, avg score : 19.9, score 27.819999378174543
# # of episode :300, avg score : 20.1, score 22.629999494180083
# # of episode :301, avg score : 20.0, score 20.98999953083694
# # of episode :302, avg score : 20.1, score 26.239999413490295
# # of episode :303, avg score : 20.2, score 26.559999406337738
# # of episode :304, avg score : 20.3, score 23.61999947205186
# # of episode :305, avg score : 20.4, score 33.359999254345894
# # of episode :306, avg score : 20.5, score 31.549999294802547
# # of episode :307, avg score : 20.6, score 21.10999952815473
# # of episode :308, avg score : 20.6, score 21.79999951273203
# # of episode :309, avg score : 20.8, score 32.18999928049743
# # of episode :310, avg score : 20.8, score 26.90999939851463
# # of episode :311, avg score : 21.0, score 26.089999416843057
# # of episode :312, avg score : 21.0, score 23.19999948143959
# # of episode :313, avg score : 20.9, score 17.599999606609344
# # of episode :314, avg score : 21.0, score 20.789999535307288
# # of episode :315, avg score : 20.9, score 21.829999512061477
# # of episode :316, avg score : 20.9, score 19.569999562576413
# # of episode :317, avg score : 21.0, score 20.809999534860253
# # of episode :318, avg score : 20.9, score 20.439999543130398
# # of episode :319, avg score : 21.1, score 29.15999934822321
# # of episode :320, avg score : 21.2, score 23.449999475851655
# # of episode :321, avg score : 21.2, score 21.849999511614442
# # of episode :322, avg score : 21.1, score 10.059999775141478
# # of episode :323, avg score : 21.3, score 35.00999921746552
# # of episode :324, avg score : 21.4, score 29.269999345764518
# # of episode :325, avg score : 21.6, score 25.75999942421913
# # of episode :326, avg score : 21.7, score 20.6099995393306
# # of episode :327, avg score : 21.8, score 39.639999113976955
# # of episode :328, avg score : 21.7, score 23.609999472275376
# # of episode :329, avg score : 21.8, score 23.809999467805028
# # of episode :330, avg score : 21.8, score 31.499999295920134
# # of episode :331, avg score : 21.8, score 18.209999592974782
# # of episode :332, avg score : 21.9, score 35.2499992121011
# # of episode :333, avg score : 22.0, score 22.289999501779675
# # of episode :334, avg score : 22.1, score 21.389999521896243
# # of episode :335, avg score : 22.1, score 15.549999652430415
# # of episode :336, avg score : 22.2, score 23.92999946512282
# # of episode :337, avg score : 22.3, score 29.269999345764518
# # of episode :338, avg score : 22.3, score 24.909999443218112
# # of episode :339, avg score : 22.3, score 26.95999939739704
# # of episode :340, avg score : 22.4, score 26.589999405667186
# # of episode :341, avg score : 22.5, score 24.04999946244061
# # of episode :342, avg score : 22.6, score 35.069999216124415
# # of episode :343, avg score : 22.7, score 23.729999469593167
# # of episode :344, avg score : 22.6, score 18.66999958269298
# # of episode :345, avg score : 22.8, score 36.5699991825968
# # of episode :346, avg score : 22.9, score 27.949999375268817
# # of episode :347, avg score : 23.0, score 29.579999338835478
# # of episode :348, avg score : 23.1, score 25.509999429807067
# # of episode :349, avg score : 23.2, score 29.219999346882105
# # of episode :350, avg score : 23.2, score 16.289999635890126
# # of episode :351, avg score : 23.2, score 19.199999570846558
# # of episode :352, avg score : 23.3, score 34.059999238699675
# # of episode :353, avg score : 23.3, score 15.999999642372131
# # of episode :354, avg score : 23.4, score 31.899999286979437
# # of episode :355, avg score : 23.4, score 25.51999942958355
# # of episode :356, avg score : 23.4, score 21.399999521672726
# # of episode :357, avg score : 23.6, score 36.849999176338315
# # of episode :358, avg score : 23.6, score 24.769999446347356
# # of episode :359, avg score : 23.7, score 30.04999932833016
# # of episode :360, avg score : 23.8, score 33.54999925009906
# # of episode :361, avg score : 23.9, score 32.61999927088618
# # of episode :362, avg score : 24.0, score 32.429999275133014
# # of episode :363, avg score : 24.0, score 18.74999958090484
# # of episode :364, avg score : 24.2, score 38.03999914973974
# # of episode :365, avg score : 24.2, score 15.239999659359455
# # of episode :366, avg score : 24.3, score 33.439999252557755
# # of episode :367, avg score : 24.5, score 34.6199992261827
# # of episode :368, avg score : 24.6, score 33.56999924965203
# # of episode :369, avg score : 24.8, score 30.28999932296574
# # of episode :370, avg score : 24.9, score 32.49999927356839
# # of episode :371, avg score : 25.0, score 24.949999442324042
# # of episode :372, avg score : 25.1, score 35.919999197125435
# # of episode :373, avg score : 25.3, score 34.74999922327697
# # of episode :374, avg score : 25.4, score 38.829999132081866
# # of episode :375, avg score : 25.6, score 36.66999918036163
# # of episode :376, avg score : 25.7, score 36.079999193549156
# # of episode :377, avg score : 25.6, score 24.849999444559216
# # of episode :378, avg score : 25.7, score 37.72999915666878
# # of episode :379, avg score : 25.8, score 34.66999922506511
# # of episode :380, avg score : 25.9, score 34.20999923534691
# # of episode :381, avg score : 26.1, score 36.579999182373285
# # of episode :382, avg score : 26.2, score 36.90999917499721
# # of episode :383, avg score : 26.3, score 35.11999921500683
# # of episode :384, avg score : 26.6, score 38.239999145269394
# # of episode :385, avg score : 26.8, score 34.89999921992421
# # of episode :386, avg score : 26.8, score 28.76999935694039
# # of episode :387, avg score : 27.0, score 35.77999920025468
# # of episode :388, avg score : 27.2, score 28.299999367445707
# # of episode :389, avg score : 27.4, score 33.77999924495816
# # of episode :390, avg score : 27.4, score 34.16999923624098
# # of episode :391, avg score : 27.4, score 24.269999457523227
# # of episode :392, avg score : 27.6, score 33.76999924518168
# # of episode :393, avg score : 27.7, score 30.32999932207167
# # of episode :394, avg score : 27.7, score 26.64999940432608
# # of episode :395, avg score : 27.8, score 31.349999299272895
# # of episode :396, avg score : 27.9, score 32.09999928250909
# # of episode :397, avg score : 28.1, score 38.6399991363287
# # of episode :398, avg score : 28.2, score 35.96999919600785
# # of episode :399, avg score : 28.2, score 30.729999313130975
# # of episode :400, avg score : 28.3, score 31.24999930150807
# # of episode :401, avg score : 28.4, score 31.159999303519726
# # of episode :402, avg score : 28.5, score 34.409999230876565
# # of episode :403, avg score : 28.6, score 37.55999916046858
# # of episode :404, avg score : 28.7, score 36.43999918550253
# # of episode :405, avg score : 28.8, score 37.199999168515205
# # of episode :406, avg score : 28.7, score 27.37999938800931
# # of episode :407, avg score : 28.8, score 28.629999360069633
# # of episode :408, avg score : 28.9, score 36.75999917834997
# # of episode :409, avg score : 29.0, score 34.409999230876565
# # of episode :410, avg score : 29.0, score 34.69999922439456
# # of episode :411, avg score : 29.0, score 21.399999521672726
# # of episode :412, avg score : 29.0, score 23.989999463781714
# # of episode :413, avg score : 29.2, score 35.97999919578433
# # of episode :414, avg score : 29.4, score 36.74999917857349
# # of episode :415, avg score : 29.5, score 36.95999917387962
# # of episode :416, avg score : 29.6, score 31.279999300837517
# # of episode :417, avg score : 29.7, score 32.01999928429723
# # of episode :418, avg score : 29.8, score 25.74999942444265
# # of episode :419, avg score : 29.8, score 34.95999921858311
# # of episode :420, avg score : 30.0, score 35.96999919600785
# # of episode :421, avg score : 30.0, score 25.689999425783753
# Solved!
# # of episode :422, avg score : 30.1, score 18.1999995931983
# Solved!
# # of episode :423, avg score : 30.1, score 39.15999912470579
# Solved!
# # of episode :424, avg score : 30.2, score 31.56999929435551
# Solved!
# # of episode :425, avg score : 30.2, score 34.23999923467636
# Solved!
# # of episode :426, avg score : 30.3, score 28.77999935671687
# Solved!
# # of episode :427, avg score : 30.3, score 37.029999172315
# Solved!
# # of episode :428, avg score : 30.4, score 35.029999217018485
# Solved!
# # of episode :429, avg score : 30.5, score 31.069999305531383
# Solved!
# # of episode :430, avg score : 30.5, score 34.599999226629734
# Solved!
# # of episode :431, avg score : 30.7, score 35.019999217242
# Solved!
# # of episode :432, avg score : 30.7, score 35.35999920964241
# Solved!
# # of episode :433, avg score : 30.8, score 34.00999923981726
# Solved!
# # of episode :434, avg score : 30.9, score 33.479999251663685
# Solved!
# # of episode :435, avg score : 31.2, score 39.37999911978841
# Solved!
# # of episode :436, avg score : 31.3, score 35.39999920874834
# Solved!
# # of episode :437, avg score : 31.4, score 37.279999166727066
# Solved!
# # of episode :438, avg score : 31.4, score 31.36999929882586
# Solved!
# # of episode :439, avg score : 31.5, score 31.48999929614365
# Solved!
# # of episode :440, avg score : 31.6, score 36.419999185949564
# Solved!
# # of episode :441, avg score : 31.7, score 38.98999912850559
# Solved!
# # of episode :442, avg score : 31.7, score 31.039999306201935
# Solved!
# # of episode :443, avg score : 31.8, score 37.8899991530925
# Solved!
# # of episode :444, avg score : 31.9, score 22.719999492168427
# Solved!
# # of episode :445, avg score : 31.6, score 15.419999655336142
# Solved!
# # of episode :446, avg score : 31.7, score 32.90999926440418
# Solved!
# # of episode :447, avg score : 31.7, score 33.65999924764037
# Solved!
# # of episode :448, avg score : 31.8, score 29.66999933682382
# Solved!
# # of episode :449, avg score : 31.8, score 35.92999919690192
# Solved!
# # of episode :450, avg score : 32.0, score 28.489999363198876
# Solved!
# # of episode :451, avg score : 32.1, score 35.839999198913574
# Solved!
# # of episode :452, avg score : 32.1, score 33.639999248087406
# Solved!
# # of episode :453, avg score : 32.3, score 34.289999233558774
# Solved!
# # of episode :454, avg score : 32.3, score 29.169999347999692
# Solved!
# # of episode :455, avg score : 32.3, score 26.05999941751361
# Solved!
# # of episode :456, avg score : 32.4, score 37.75999915599823
# Solved!

# %%
torch.save(mu.state_dict(), 'mu.pth')
torch.save(q.state_dict(), 'q.pth')
